# %%
import pandas as pd

# %%
vqa_parquet = pd.read_parquet("/share/pierson/matt/mllmsci/outputs/vqa/results.parquet")

# %%
vqa_parquet['prompt'].values[0]
# Out:
# 'You are tasked with analyzing images to determine whether they depict a flooded street. Your response must be a concise, direct answer to the question "Does this image show a flooded street?" with a clear "Yes" or "No" prediction.\n\nKey considerations:\n- A flooded street is defined by visible standing water that covers the road surface, often reaching significant depths (e.g., up to vehicle tires or higher), and may include submerged vehicles or water reflecting light in a way that indicates depth.\n- Wet roads due to rain alone (e.g., slick pavement, reflections, raindrops on windshields) do not qualify as flooded unless there is clear evidence of accumulated water.\n- The presence of water reaching the wheels of vehicles, submerging parts of the road, or creating a reflective surface that suggests depth is a strong indicator of flooding.\n- The context of the scene (e.g., urban streets, highways, underpasses) is relevant, but the primary focus is on the physical evidence of floo
# ...

# %%
vqa_parquet['model_response'].value_counts()
# Out:
# model_response
# No     924877
# Yes      1335
# Name: count, dtype: int64
