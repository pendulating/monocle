# %%
import pandas as pd

# %%
lyu_basic_nli = pd.read_parquet("/share/pierson/matt/mllmsci/outputs/vqa/bayflood_926k_10pct_lyu_basic_with_nli.parquet")

# %%
lyu_basic_nli.head()
# Out:
#                                 sample_id  \
# 0  nexar_53afeec954a80d924012432cb70c1081
# 1  nexar_66384e02c4b2ceda1b331f44ee45e950
# 2  nexar_85283d2860cd54b22ccef4a210602830
# 3  nexar_4bba636e205d574c150ba661ba3d5e35
# 4  nexar_9eab3d72765f7764cd4d1f0171cac6ba
#
#                                               prompt  \
# 0  Analyze and estimate the deepest floodwater le...
# 1  Analyze and estimate the deepest floodwater le...
# 2  Analyze and estimate the deepest floodwater le...
# 3  Analyze and estimate the deepest floodwater le...
# 4  Analyze and estimate the deepest floodwater le...
#
#                                           image_path image_url image_base64  \
# 0  /share/ju/nexar_data/2023/2023-09-29/604222325...      None         None
# 1  /share/ju/nexar_data/2023/2023-09-29/604222325...      None         None
# 2  /share/ju/nexar_data/2023/2023-09-29/604222325...      None         None
# 3  /share/ju/nexar_data/2023/2023-09-29/604222325...      None         None
# ...

# %%
lyu_basic_nli['nli_label'].value_counts()
# Out:
# nli_label
# yes, flooded       53525
# no, not flooded    39096
# Name: count, dtype: int64

# %%
# randomly sample 250 rows from each class and write to csv 
lyu_basic_nli_samples = lyu_basic_nli.groupby('nli_label').apply(lambda x: x.sample(250))
lyu_basic_nli_samples.to_csv("/share/pierson/matt/mllmsci/outputs/vqa/bayflood_926k_10pct_lyu_basic_with_nli_samples.csv", index=False)
# Out:
# /tmp/ipykernel_2848249/2619138995.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   lyu_basic_nli_samples = lyu_basic_nli.groupby('nli_label').apply(lambda x: x.sample(250))

# %%
# now lyu advanced 
lyu_advanced_nli = pd.read_parquet("/share/pierson/matt/mllmsci/outputs/vqa/bayflood_926k_10pct_lyu_advanced_with_nli_20260120.parquet")

# %%
lyu_advanced_nli.head()
# Out:
#                                 sample_id  \
# 0  nexar_53afeec954a80d924012432cb70c1081
# 1  nexar_66384e02c4b2ceda1b331f44ee45e950
# 2  nexar_85283d2860cd54b22ccef4a210602830
# 3  nexar_4bba636e205d574c150ba661ba3d5e35
# 4  nexar_9eab3d72765f7764cd4d1f0171cac6ba
#
#                                               prompt  \
# 0  As an expert in assessing floodwater levels fr...
# 1  As an expert in assessing floodwater levels fr...
# 2  As an expert in assessing floodwater levels fr...
# 3  As an expert in assessing floodwater levels fr...
# 4  As an expert in assessing floodwater levels fr...
#
#                                           image_path image_url image_base64  \
# 0  /share/ju/nexar_data/2023/2023-09-29/604222325...      None         None
# 1  /share/ju/nexar_data/2023/2023-09-29/604222325...      None         None
# 2  /share/ju/nexar_data/2023/2023-09-29/604222325...      None         None
# 3  /share/ju/nexar_data/2023/2023-09-29/604222325...      None         None
# ...

# %%
lyu_advanced_nli['nli_label'].value_counts()
# Out:
# nli_label
# no, not flooded    84652
# yes, flooded        7969
# Name: count, dtype: int64

# %%
# randomly sample 250 rows from each class and write to csv 
lyu_advanced_nli_samples = lyu_advanced_nli.groupby('nli_label').apply(lambda x: x.sample(250))
lyu_advanced_nli_samples.to_csv("/share/pierson/matt/mllmsci/outputs/vqa/bayflood_926k_10pct_lyu_advanced_with_nli_samples.csv", index=False)
# Out:
# /tmp/ipykernel_2848249/3395609038.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   lyu_advanced_nli_samples = lyu_advanced_nli.groupby('nli_label').apply(lambda x: x.sample(250))

# %%
# now do yang advanced 
yang_advanced_nli = pd.read_parquet("/share/pierson/matt/mllmsci/outputs/vqa/bayflood_926k_10pct_yang_advanced_with_nli.parquet")

# %%
yang_advanced_nli['nli_label'].value_counts()
# Out:
# nli_label
# no, not flooded    92354
# yes, flooded         267
# Name: count, dtype: int64

# %%
# randomly sample 250 rows from each class and write to csv 
yang_advanced_nli_samples = yang_advanced_nli.groupby('nli_label').apply(lambda x: x.sample(250))
yang_advanced_nli_samples.to_csv("/share/pierson/matt/mllmsci/outputs/vqa/bayflood_926k_10pct_yang_advanced_with_nli_samples.csv", index=False)
# Out:
# /tmp/ipykernel_2848249/3802877598.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   yang_advanced_nli_samples = yang_advanced_nli.groupby('nli_label').apply(lambda x: x.sample(250))

# %%
# now, liu floodvision 
liu_floodvision_nli = pd.read_parquet("/share/pierson/matt/mllmsci/outputs/vqa/bayflood_926k_10pct_liu_floodvision_with_nli.parquet")

# %%
liu_floodvision_nli['nli_label'].value_counts()
# Out:
# nli_label
# yes, passable       68175
# uncertain           24043
# no, not passable      392
# not applicable         11
# Name: count, dtype: int64

# %%
# randomly sample 250 rows from 'no, not passable' and union of all other classes 
liu_floodvision_not_passable_sample = liu_floodvision_nli[liu_floodvision_nli['nli_label'] == 'no, not passable'].sample(250)
liu_floodvision_other_sample = liu_floodvision_nli[liu_floodvision_nli['nli_label'] != 'no, not passable'].sample(250)
liu_floodvision_samples = pd.concat([liu_floodvision_not_passable_sample, liu_floodvision_other_sample])

liu_floodvision_samples['nli_label'].value_counts()

# now, liu floodvision
# Out:
# nli_label
# no, not passable    250
# yes, passable       193
# uncertain            57
# Name: count, dtype: int64

# %%
liu_floodvision_samples.to_csv("/share/pierson/matt/mllmsci/outputs/vqa/bayflood_926k_10pct_liu_floodvision_with_nli_samples.csv", index=False)
